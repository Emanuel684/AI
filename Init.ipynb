# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 250.9/250.9 kB 20.5 MB/s eta 0:00:00
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 238.4/238.4 kB 32.9 MB/s eta 0:00:00
# Collecting tensorflow==2.10.0
#   Downloading tensorflow-2.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━ 578.0/578.0 MB 1.1 MB/s eta 0:00:00
# Collecting keras-tuner==1.1.3
#   Downloading keras_tuner-1.1.3-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 135.7/135.7 kB 19.4 MB/s eta 0:00:00
# Collecting scikit-learn==1.3.2
#   Downloading scikit_learn-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 10.8/10.8 MB 65.7 MB/s eta 0:00:00
# Collecting shap==0.43.0
#   Downloading shap-0.43.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (532 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 532.9/532.9 kB 31.8 MB/s eta 0:00:00
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /root/venv/lib/python3.10/site-packages (from tensorflow==2.10.0->-r ./requirements.txt (line 4)) (1.70.0)
# Requirement already satisfied: astunparse>=1.6.0 in /root/venv/lib/python3.10/site-packages (from tensorflow==2.10.0->-r ./requirements.txt (line 4)) (1.6.3)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 42.6/42.6 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /root/venv/lib/python3.10/site-packages (from tensorflow==2.10.0->-r ./requirements.txt (line 4)) (65.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /root/venv/lib/python3.10/site-packages (from tensorflow==2.10.0->-r ./requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: termcolor>=1.1.0 in /root/venv/lib/python3.10/site-packages (from tensorflow==2.10.0->-r ./requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: packaging in /root/venv/lib/python3.10/site-packages (from tensorflow==2.10.0->-r ./requirements.txt (line 4)) (24.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /root/venv/lib/python3.10/site-packages (from tensorflow==2.10.0->-r ./requirements.txt (line 4)) (0.37.1)
# Requirement already satisfied: h5py>=2.9.0 in /root/venv/lib/python3.10/site-packages (from tensorflow==2.10.0->-r ./requirements.txt (line 4)) (3.12.1)
# Requirement already satisfied: flatbuffers>=2.0 in /root/venv/lib/python3.10/site-packages (from tensorflow==2.10.0->-r ./requirements.txt (line 4)) (25.2.10)
# Requirement already satisfied: google-pasta>=0.1.1 in /root/venv/lib/python3.10/site-packages (from tensorflow==2.10.0->-r ./requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /root/venv/lib/python3.10/site-packages (from tensorflow==2.10.0->-r ./requirements.txt (line 4)) (1.14.1)
# Collecting tensorboard<2.11,>=2.10
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 5.9/5.9 MB 43.9 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /root/venv/lib/python3.10/site-packages (from tensorflow==2.10.0->-r ./requirements.txt (line 4)) (2.1.0)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /root/venv/lib/python3.10/site-packages (from tensorflow==2.10.0->-r ./requirements.txt (line 4)) (3.4.0)
# Collecting keras<2.11,>=2.10.0
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━��━━━━━━━━━━━━━━ 1.7/1.7 MB 34.3 MB/s eta 0:00:00
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 1.1/1.1 MB 51.2 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /root/venv/lib/python3.10/site-packages (from tensorflow==2.10.0->-r ./requirements.txt (line 4)) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in /root/venv/lib/python3.10/site-packages (from tensorflow==2.10.0->-r ./requirements.txt (line 4)) (1.25.2)
# Requirement already satisfied: six>=1.12.0 in /root/venv/lib/python3.10/site-packages (from tensorflow==2.10.0->-r ./requirements.txt (line 4)) (1.17.0)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 438.7/438.7 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /root/venv/lib/python3.10/site-packages (from keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (2.32.3)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: ipython in /root/venv/lib/python3.10/site-packages (from keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (8.32.0)
# Requirement already satisfied: joblib>=1.1.1 in /root/venv/lib/python3.10/site-packages (from scikit-learn==1.3.2->-r ./requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: scipy>=1.5.0 in /root/venv/lib/python3.10/site-packages (from scikit-learn==1.3.2->-r ./requirements.txt (line 6)) (1.9.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /root/venv/lib/python3.10/site-packages (from scikit-learn==1.3.2->-r ./requirements.txt (line 6)) (3.5.0)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Collecting numba
#   Downloading numba-0.61.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 3.8/3.8 MB 87.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /root/venv/lib/python3.10/site-packages (from shap==0.43.0->-r ./requirements.txt (line 7)) (2.1.4)
# Requirement already satisfied: cloudpickle in /root/venv/lib/python3.10/site-packages (from shap==0.43.0->-r ./requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: tqdm>=4.27.0 in /root/venv/lib/python3.10/site-packages (from shap==0.43.0->-r ./requirements.txt (line 7)) (4.67.1)
# Collecting et-xmlfile
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Collecting scipy>=1.5.0
#   Downloading scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 37.6/37.6 MB 32.5 MB/s eta 0:00:00
# Collecting sklearn-compat<1,>=0.1
#   Downloading sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.10.0->-r ./requirements.txt (line 4)) (0.45.1)
# Requirement already satisfied: markdown>=2.6.8 in /root/venv/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r ./requirements.txt (line 4)) (3.7)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 4.9/4.9 MB 59.9 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=1.0.1 in /root/venv/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r ./requirements.txt (line 4)) (3.1.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /root/venv/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r ./requirements.txt (line 4)) (2.38.0)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 781.3/781.3 kB 39.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/venv/lib/python3.10/site-packages (from requests->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/venv/lib/python3.10/site-packages (from requests->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.10/site-packages (from requests->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /root/venv/lib/python3.10/site-packages (from requests->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (2025.1.31)
# Requirement already satisfied: pexpect>4.3 in /root/venv/lib/python3.10/site-packages (from ipython->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (4.9.0)
# Requirement already satisfied: matplotlib-inline in /root/venv/lib/python3.10/site-packages (from ipython->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (0.1.7)
# Requirement already satisfied: pygments>=2.4.0 in /root/venv/lib/python3.10/site-packages (from ipython->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (2.19.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /root/venv/lib/python3.10/site-packages (from ipython->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (3.0.50)
# Requirement already satisfied: jedi>=0.16 in /root/venv/lib/python3.10/site-packages (from ipython->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (0.17.2)
# Requirement already satisfied: traitlets>=5.13.0 in /root/venv/lib/python3.10/site-packages (from ipython->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (5.14.3)
# Requirement already satisfied: decorator in /root/venv/lib/python3.10/site-packages (from ipython->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: exceptiongroup in /root/venv/lib/python3.10/site-packages (from ipython->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (1.2.2)
# Requirement already satisfied: stack_data in /root/venv/lib/python3.10/site-packages (from ipython->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (0.6.3)
# Collecting llvmlite<0.45,>=0.44.0dev0
#   Downloading llvmlite-0.44.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 42.4/42.4 MB 41.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/venv/lib/python3.10/site-packages (from pandas->shap==0.43.0->-r ./requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.10/site-packages (from pandas->shap==0.43.0->-r ./requirements.txt (line 7)) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.10/site-packages (from pandas->shap==0.43.0->-r ./requirements.txt (line 7)) (2025.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /root/venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r ./requirements.txt (line 4)) (5.5.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /root/venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r ./requirements.txt (line 4)) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /root/venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r ./requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /root/venv/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r ./requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /root/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /root/venv/lib/python3.10/site-packages (from pexpect>4.3->ipython->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: wcwidth in /root/venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /root/venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r ./requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: asttokens>=2.1.0 in /root/venv/lib/python3.10/site-packages (from stack_data->ipython->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: pure-eval in /root/venv/lib/python3.10/site-packages (from stack_data->ipython->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /root/venv/lib/python3.10/site-packages (from stack_data->ipython->keras-tuner==1.1.3->-r ./requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /root/venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r ./requirements.txt (line 4)) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /root/venv/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r ./requirements.txt (line 4)) (3.2.2)
# Installing collected packages: tensorboard-plugin-wit, kt-legacy, keras, tensorflow-estimator, tensorboard-data-server, slicer, scipy, protobuf, llvmlite, keras-preprocessing, gast, et-xmlfile, scikit-learn, openpyxl, numba, sklearn-compat, shap, google-auth-oauthlib, tensorboard, imbalanced-learn, tensorflow, keras-tuner
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.15.0
#     Uninstalling tensorflow-estimator-2.15.0:
#       Successfully uninstalled tensorflow-estimator-2.15.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.3
#     Uninstalling scipy-1.9.3:
#       Successfully uninstalled scipy-1.9.3
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.6
#     Uninstalling protobuf-4.25.6:
#       Successfully uninstalled protobuf-4.25.6
#   Attempting uninstall: gast
#     Found existing installation: gast 0.6.0
#     Uninstalling gast-0.6.0:
#       Successfully uninstalled gast-0.6.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.1.3
#     Uninstalling scikit-learn-1.1.3:
#       Successfully uninstalled scikit-learn-1.1.3
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.1
#     Uninstalling google-auth-oauthlib-1.2.1:
#       Successfully uninstalled google-auth-oauthlib-1.2.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.1
#     Uninstalling tensorflow-2.15.1:
#       Successfully uninstalled tensorflow-2.15.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# snowflake-snowpark-python 1.26.0 requires protobuf<6,>=3.20, but you have protobuf 3.19.6 which is incompatible.
# grpcio-status 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.19.6 which is incompatible.
# grpc-google-iam-v1 0.13.1 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# googleapis-common-protos 1.65.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# google-cloud-spanner 3.49.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.19.6 which is incompatible.
# Successfully installed et-xmlfile-2.0.0 gast-0.4.0 google-auth-oauthlib-0.4.6 imbalanced-learn-0.13.0 keras-2.10.0 keras-preprocessing-1.1.2 keras-tuner-1.1.3 kt-legacy-1.0.5 llvmlite-0.44.0 numba-0.61.2 openpyxl-3.1.5 protobuf-3.19.6 scikit-learn-1.3.2 scipy-1.15.2 shap-0.43.0 sklearn-compat-0.1.3 slicer-0.0.7 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
